# %%
import random


IP = [58, 50, 42, 34, 26, 18, 10, 2,
      60, 52, 44, 36, 28, 20, 12, 4,
      62, 54, 46, 38, 30, 22, 14, 6,
      64, 56, 48, 40, 32, 24, 16, 8,
      57, 49, 41, 33, 25, 17, 9, 1,
      59, 51, 43, 35, 27, 19, 11, 3,
      61, 53, 45, 37, 29, 21, 13, 5,
      63, 55, 47, 39, 31, 23, 15, 7]

FP = [40, 8, 48, 16, 56, 24, 64, 32,
      39, 7, 47, 15, 55, 23, 63, 31,
      38, 6, 46, 14, 54, 22, 62, 30,
      37, 5, 45, 13, 53, 21, 61, 29,
      36, 4, 44, 12, 52, 20, 60, 28,
      35, 3, 43, 11, 51, 19, 59, 27,
      34, 2, 42, 10, 50, 18, 58, 26,
      33, 1, 41, 9, 49, 17, 57, 25]


E = [32, 1, 2, 3, 4, 5,
     4, 5, 6, 7, 8, 9,
     8, 9, 10, 11, 12, 13,
     12, 13, 14, 15, 16, 17,
     16, 17, 18, 19, 20, 21,
     20, 21, 22, 23, 24, 25,
     24, 25, 26, 27, 28, 29,
     28, 29, 30, 31, 32, 1]

S_BOX = [

# S1
[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7,
 0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8,
 4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0,
 15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13],

# S2
[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10,
 3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5,
 0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15,
 13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9],

# S3
[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8,
 13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1,
 13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7,
 1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12],

# S4
[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15,
 13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9,
 10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4,
 3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14],

# S5
[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9,
 14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6,
 4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14,
 11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3],

# S6
[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11,
 10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8,
 9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6,
 4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13],

# S7
[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1,
 13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6,
 1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2,
 6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12],


[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7,
 1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2,
 7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8,
 2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11],
]


P = [16, 7, 20, 21, 29, 12, 28, 17,
     1, 15, 23, 26, 5, 18, 31, 10,
     2, 8, 24, 14, 32, 27, 3, 9,
     19, 13, 30, 6, 22, 11, 4, 25]


PC1 = [57, 49, 41, 33, 25, 17, 9,
       1, 58, 50, 42, 34, 26, 18,
       10, 2, 59, 51, 43, 35, 27,
       19, 11, 3, 60, 52, 44, 36,
       63, 55, 47, 39, 31, 23, 15,
       7, 62, 54, 46, 38, 30, 22,
       14, 6, 61, 53, 45, 37, 29,
       21, 13, 5, 28, 20, 12, 4]

PC2 = [14, 17, 11, 24, 1, 5, 3, 28,
       15, 6, 21, 10, 23, 19, 12, 4,
       26, 8, 16, 7, 27, 20, 13, 2,
       41, 52, 31, 37, 47, 55, 30, 40,
       51, 45, 33, 48, 44, 49, 39, 56,
       34, 53, 46, 42, 50, 36, 29, 32]


SHIFT = [1, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1]

def permute(k, arr, n):
    permutation = ""
    for i in range(n):
        permutation += k[arr[i] - 1]
    return permutation

def shift_left(k, nth_shifts):
    return k[nth_shifts:] + k[:nth_shifts]

def xor(a, b):
    return ''.join('0' if x == y else '1' for x, y in zip(a, b))

def generate_keys(key):
    keys = []
    key = permute(key, PC1, 56)
    left = key[:28]
    right = key[28:]
    for i in range(16):
        left = shift_left(left, SHIFT[i])
        right = shift_left(right, SHIFT[i])
        combined_key = left + right
        round_key = permute(combined_key, PC2, 48)
        keys.append(round_key)
    return keys

def s_box_substitute(expanded_half):
    output = ""
    for i in range(8):
        block = expanded_half[i*6:(i+1)*6]
        row = int(block[0] + block[5], 2)
        col = int(block[1:5], 2)
        val = S_BOX[i][row*16 + col]
        output += format(val, '04b')
    return output

def f_function(right, key):
    expanded = permute(right, E, 48)
    xor_x = xor(expanded, key)
    sbox_str = s_box_substitute(xor_x)
    return permute(sbox_str, P, 32)

def encrypt(pt, key):
    pt = permute(pt, IP, 64)
    left = pt[:32]
    right = pt[32:]
    keys = generate_keys(key)

    for i in range(16):
        expanded_right = f_function(right, keys[i])
        temp = xor(left, expanded_right)
        left = right
        right = temp

    combined = right + left
    cipher_text = permute(combined, FP, 64)
    return cipher_text

def decrypt(ct, key):
    ct = permute(ct, IP, 64)
    left = ct[:32]
    right = ct[32:]
    keys = generate_keys(key)

    for i in range(15, -1, -1):
        expanded_right = f_function(right, keys[i])
        temp = xor(left, expanded_right)
        left = right
        right = temp

    combined = right + left
    plain_text = permute(combined, FP, 64)
    return plain_text

def pad_text(text):
    padding_length = 8 - (len(text) % 8)
    return text + chr(padding_length) * padding_length

def unpad_text(padded_text):
    padding_length = ord(padded_text[-1])
    return padded_text[:-padding_length]

def text_to_binary(text):
    return ''.join(format(ord(char), '08b') for char in text)

def binary_to_text(binary):
    return ''.join(chr(int(binary[i:i+8], 2)) for i in range(0, len(binary), 8))


key = ''.join(random.choice('01') for _ in range(64))
padded_text = pad_text(original_text)
binary_padded_text = text_to_binary(padded_text)

print("Original Text:", original_text)
print("Padded Text:", padded_text)
print("Binary Padded Text:", binary_padded_text)

cipher_text = ""
for i in range(0, len(binary_padded_text), 64):
    block = binary_padded_text[i:i+64]
    if len(block) < 64:
        block = block.ljust(64, '0')
    cipher_text += encrypt(block, key)

print("Cipher Text (binary):", cipher_text)

decrypted_binary = ""
for i in range(0, len(cipher_text), 64):
    block = cipher_text[i:i+64]
    decrypted_binary += decrypt(block, key)

decrypted_padded_text = binary_to_text(decrypted_binary)
decrypted_text = unpad_text(decrypted_padded_text)

print("Decrypted Padded Text:", decrypted_padded_text)
print("Decrypted Text:", decrypted_text)
# Out:
# Original Text: Hello, World!
# Padded Text: Hello, World!
# Binary Padded Text: 01001000011001010110110001101100011011110010110000100000010101110110111101110010011011000110010000100001000000110000001100000011
# Cipher Text (binary): 11001001010100010000011101101001010001010000111001111110010100001000000010001001010100000100011010011011100001100100101000001110
# Decrypted Padded Text: Hello, World!
# Decrypted Text: Hello, World!
